# %% [markdown]
# <a href="https://colab.research.google.com/github/Caroline-Calixto/python-fundamentals/blob/main/UFABC_Exerc%C3%ADcios_em_aula.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercícios

# %% [markdown]
# **Execício 1**
#
# O festival de música Pie in the Sky acontece todo ano. Você e suas amigas finalmente acreditam que têm idade suficiente para poder ter acesso ao evento.
#
# Para ter acesso liberado ao festival, você e suas amigas precisam formar um grupo de pelo menos 4 pessoas, que juntas somam no mínimo 77 anos.
#
# Faça um programa que leia a idade de cada uma das suas amigas e verifique se vocês conseguirão entrar no evento.
#
# - **Entradas:** Um número inteiro n, que representa o número de integrantes do grupo, e a idade de cada uma  das integrantes.
#
# - **Saída:** O programa deve retornar se o grupo consegue ou não entrar no festival.

# %%
# MINHA RESPOSTA

qtdgrupo = int(input("Informe quantas pessoas tem no seu grupo: "))

if qtdgrupo >= 4:
  print(f"seu grupo tem {qtdgrupo} pessoas")

  idadeGrupo = 0
  for pessoas in range (qtdgrupo):
    idadeInformada = int(input("me informe a idade de cada integrante do seu grupo: "))
    idadeGrupo = idadeInformada + idadeGrupo
    print(idadeGrupo)

else:
  print("seu grupo precisa ter pelo menos 4 pessoas")

if idadeGrupo >= 77:
  print("seu grupo pode entrar no festival")
else:
  print("seu grupo não pode entrar no festival")
# Out:
# Informe quantas pessoas tem no seu grupo: 4
# seu grupo tem 4 pessoas
# me informe a idade de cada integrante do seu grupo: 15
# 15
# me informe a idade de cada integrante do seu grupo: 18
# 33
# me informe a idade de cada integrante do seu grupo: 24
# 57
# me informe a idade de cada integrante do seu grupo: 30
# 87
# seu grupo pode entrar no festival

# %%
# RESPOSTA DA PROFESSORA
n = int(input("Digite o número de participantes: "))

if n < 4:
  n = int(input("O grupo deve ter pelo menos 4 participantes. Digite o número de participantes: "))

idades = 0
for participante in range(n):
  idade = int(input("Digite a idade da participante: "))
  idades += idade

if idades < 77:
  print("O grupo não poderá entrar no festival")
else:
  print("O grupo pode entrar no festival")

# %% [markdown]
# **Exercício 2**
#
# No hortifruti que Marina trabalha existem 150 variações de produtos disponíveis para as clientes.
#
# Para entender um pouco mais sobre o perfil de compra das clientes, as analistas de dados da empresa resolveram verificar quais tipos de produtos as clientes compram em cada pedido.
#
# Utilize as estruturas break e for para ajudar Marina a criar um programa que tenha como entrada os nomes dos produtos que a cliente comprou em um pedido e que retorne quantos produtos diferentes foram comprados.
#
# - **Entrada:** O programa deve receber, enquanto for possível inserir um produto diferente, o nome de cada produto comprado.
#
# - **Saída:** O código retornará a quantidade de produtos comprados.

# %%
#
# Out:
#   File "/tmp/ipykernel_2141/2131834763.py", line 5
#     continuar = bool print("registrar mais produtos?")
#                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# Você e sua vizinha Vanessa foram acampar no gramado da sua casa e decidiram enterrar um cofre com 50 reais e um bilhete no seu quintal, para as gerações futuras. No bilhete, vocês escreveram as instruções do quadro:
#
# 1) Aqui há um tesouro para quem conseguir desvendar minha senha;
#
# 2) Minha senha possui 4 dígitos: são duas letras minúsculas e dois números;
#
# 3) Você tem infinitas tentativas;
#
# 4) Aqui vai uma dica pra te ajudar: dois patinhos alternados na casa rosa.
#
#
# * Vocês escolheram como senha a sequência “2c2r”.
#
# Escreva um programa que funcione da mesma forma que o cofre, tendo como entrada uma sequência de 4 dígitos e que rode até alcançar a sequência desejada.

# %%
# resolução
# o laço só acaba quando a pessoa digitar a senha correta
senha = input("digite uma senha de 4 digitos:")

while senha != '2c2r':
  print("senha invalida", senha)
  break
# Out:
# digite uma senha de 4 digitos:4444
# senha invalida 4444

# %% [markdown]
# **Exercicio 3**
#
# Ajude a professora Anna a completar o relatório do seu curso
# de Python. Ela precisa informar quantas das estudantes irão
# receber o certificado ao fim do curso.
#
# Para receber o certificado, a aluna precisa ter presença no
# mínimo em 3 das 5 aulas.
#
# Ela informa que a turma possui 10 estudantes com as
# seguintes quantidades de faltas, em ordem de chamada:
#
# [0,3,0,0,0,1,2,1,1,0]
#
# Faça um programa que recebe o número de chamada da aluna e
# imprime a sua quantidade de faltas

# %%
#criar lista de faltas
listaFaltas = [0,3,0,0,0,1,2,1,1,0]

#receber o numero da aluna
numeroAluna = int(input("digite o numero da aluna:"))

#exibir falta da aluna conforme posição na lista
print("Quantidade de faltas da aluna 1: ", listaFaltas[numeroAluna -1])
# Out:
# digite o numero da aluna:2
# Quantidade de faltas da aluna 1:  3

# %% [markdown]
# **Exericio 4**
#
#
# Após Anna escrever a lista com as faltas das alunas, ela
# percebeu que cometeu dois erros na conferência da lista
# de presença. A terceira aluna da lista teve na verdade
# duas faltas ao invés de zero e a oitava aluna teve três
# faltas ao invés de uma.
#
# Escreva um código simulando essa alteração na lista,
# utilizando a alteração de itens por índice.
# faltas_iniciais = [0,3,0,0,0,1,2,1,1,0]

# %%
#alterando lista de faltas (Update)

#exibir lista de chamadaXfaltas
listaFaltas = [0,3,0,0,0,1,2,1,1,0]

#digite o numero da chamada
numeroAluna = int(input("digite o numero da chamada da aluna:"))

#alterar quantidade de faltas
faltaCorreta = int(input("Informe a quantidade correta de faltas:"))
listaFaltas[numeroAluna] = faltaCorreta

#atualizar lista com novo valor de falta
listaFaltas.insert(numeroAluna, faltaCorreta)
print(listaFaltas)

#exibir faltas corrigidas da aluna
print(f"aluna {numeroAluna} teve suas faltas alteradas para {listaFaltas[numeroAluna]}")
